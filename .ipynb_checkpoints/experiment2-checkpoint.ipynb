# %% [markdown]
# <h2 style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# 📐 Signal Equations for Experiment 2
# </h2>
#
# ---
#
# <p style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# Basic Time Operations (Continuous):
# </p>
#
# $$
# \Huge x(t) = u(-t),
#       x(t) = u(t-2),
#       x(t) = u(2t),
#       x(t) = u(2t-2)
# $$
#
# <hr>
#
# <p style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# Basic Time Operations (Discrete):
# </p>
#
# $$
# \Huge x(n) = u(-n),
#       x(n) = u(n-2),
#       x(n) = u(2n),
#       x(n) = u(2n-2)
# $$
# <hr>
#
# <p style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# Impulse From Unit:
# </p>
#
# $$
# \Huge
# \delta(t) = u(t) - u(t-1)
# $$
#
# <hr>
#
# <p style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# Scaled Shifted Exponential:
# </p>
#
# $$
# \Huge
# x(t) = -2^{n}u(-n-1)
# $$
#
# <hr>
#
# <p style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# Scaled Rect:
# </p>
#
# $$
# \Huge
# x(t) =
# \begin{cases}
#     A, & t = 0 \\
#     0, & \text{otherwise}
# \end{cases}
# $$
#
# <hr>
#
# <p style="font-family:'Montserrat', sans-serif; font-weight:600; text-transform: uppercase;">
# Scaled And Shifted Unit Signal:
# </p>
#
# $$
# \Huge
# x(t) =
# \begin{cases}
#     A, & |t| \le T \\
#     0, & \text{otherwise}
# \end{cases}
# $$
#
# <hr>
